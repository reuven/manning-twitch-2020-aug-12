# %%
s = 'abcd'
len(s)
# Out:
# 4

# %%
x = len(s)
type(x)
# Out:
# int

# %%
x
# Out:
# 4

# %%
x = s.upper()

# %%
x
# Out:
# 'ABCD'

# %%
type(x)
# Out:
# str

# %%
x = s.upper

# %%
x
# Out:
# <function str.upper()>

# %%
x is s.upper
# Out:
# False

# %%
s.upper()
# Out:
# 'ABCD'

# %%
x()
# Out:
# 'ABCD'

# %%
d = {'a':1, 'b':2, 'c':3}

for key, value in d.items():
    print(f'{key}: {value}')
# Out:
# a: 1
# b: 2
# c: 3

# %%
d = {'a':1, 'b':2, 'c':3}

for key, value in d.items:
    print(f'{key}: {value}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f556797c3125> in <module>
#       1 d = {'a':1, 'b':2, 'c':3}
#       2
# ----> 3 for key, value in d.items:
#       4     print(f'{key}: {value}')
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
def hello():
    return 'Hello!'

# %%
type(hello)
# Out:
# function

# %%
type(hello())
# Out:
# str
